# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from keras.models import Sequential
from keras.layers.recurrent import LSTM, GRU
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.embeddings import Embedding
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.layers import GlobalMaxPooling1D, Conv1D, MaxPooling1D, Flatten, Bidirectional, SpatialDropout1D
from keras.preprocessing import sequence, text
from keras.callbacks import EarlyStopping
# Out:
# C:\Users\narendran.thesma\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
data = pd.read_csv("Japan_Not_Encoded.csv", encoding='utf-8')
data.head()
# Out:
#   COMPANY COUNTRY DISTRIBUTOR  ARTICLE ID MODEL NUMBER  \
# 0    Nike   Japan    Own eCom  BG0387-001       BG0387
# 1    Nike   Japan    Own eCom  839240-001       839240
# 2    Nike   Japan    Own eCom  GL0783-101       GL0783
# 3    Nike   Japan    Own eCom  GL0781-101       GL0781
# 4    Nike   Japan    Own eCom  AC3877-005       AC3877
#
#               ARTICLE NAME        SUBBRAND SPORTS CATEGORY PRODUCT DIVISION  \
# 0     ナイキ コア ハーフ KV ゴルフバッグ     Performance            Golf      Accessories
# 1     ナイキ コルテッツ QS キッズシューズ  Sport Inspired       Lifestyle         Footwear
# 2  ナイキ レジン スピード レッド ゴルフボール     Performance            Golf      Accessories
# 3  ナイキ レジン ツアー ブラック ゴルフボール     Performance            Golf      Accessories
# 4    ナイキ ATG スピード ジャンプ ロープ     Performance        Training      Accessories
#
#              PRODUCT GROUP                        ...                          \
# 0                     Bags                        ...
# 1  Sport Inspired Footwear                        ...
# 2          Sport Equipment                        ...
# 3          Sport Equipment                        ...
# 4          Sport Equipment                        ...
#
#   CURRENT PRICE IN EUR INITIAL PRICE IN SELECTED CURRENCY  \
# 0               99.144                            116.640
# 1               62.820                             82.620
# 2               31.104                             31.104
# 3               28.764                             58.320
# 4               28.188                             28.188
#
#   CURRENT PRICE IN SELECTED CURRENCY SELECTED CURRENCY  \
# 0                             99.144               EUR
# 1                             62.820               EUR
# 2                             31.104               EUR
# 3                             28.764               EUR
# 4                             28.188               EUR
#
#   PRODUCT INTRODUCTION DATE    DISCOUNTED SINCE PRODUCT EXIT DATE  \
# 0                 2/22/2016          12/26/2016          1/2/2017
# 1                 2/22/2016            4/5/2016         7/26/2016
# 2                 2/15/2016  Not discounted yet         8/29/2016
# 3                 2/15/2016           2/27/2017         6/27/2017
# 4                 2/15/2016  Not discounted yet         7/19/2016
#
#                                  PRODUCT DESCRIPTION  \
# 0  整理しやすいゴルフバッグ。快適な持ち運び。 ナイキ コア ハーフ KV ゴルフバッグは、専用...
# 1  高級感のあるレトロスタイル   ナイキ コルテッツ QS キッズシューズは、上質なレザーのア...
# 2  高初速でより遠くへ ナイキ レジン スピード レッド ゴルフボールは、更にソフトになった新開...
# 3  低スピンでより遠くへ ナイキ レジン ツアー ブラック ゴルフボールは、更にソフトになったR...
# 4  軽く、速く、カスタマイズも可能。 ナイキ ATG スピード ジャンプ ロープは、滑りにくいボ...
#
#                                          PRODUCT URL  \
# 0  http://store.nike.com/jp/ja_jp/pd/%25E3%2583%2...
# 1  http://store.nike.com/jp/ja_jp/pd/%25E3%2583%2...
# 2  http://store.nike.com/jp/ja_jp/pd/%25E3%2583%2...
# 3  http://store.nike.com/jp/ja_jp/pd/%25E3%2583%2...
# 4  http://store.nike.com/jp/ja_jp/pd/%25E3%2583%2...
#
#                                     IMAGE-SERVER URL
# 0  http://usporamap287.am.adsint.biz/zoomimages/1...
# 1  http://usporamap287.am.adsint.biz/zoomimages/1...
# 2  http://usporamap287.am.adsint.biz/zoomimages/1...
# 3  http://usporamap287.am.adsint.biz/zoomimages/1...
# 4  http://usporamap287.am.adsint.biz/zoomimages/1...
#
# [5 rows x 32 columns]

# %%
data.columns
# Out:
# Index(['COMPANY', 'COUNTRY', 'DISTRIBUTOR', 'ARTICLE ID', 'MODEL NUMBER',
#        'ARTICLE NAME', 'SUBBRAND', 'SPORTS CATEGORY', 'PRODUCT DIVISION',
#        'PRODUCT GROUP', 'PRODUCT TYPE', 'FRANCHISE', 'TECHNOLOGIES',
#        'COLOUR GROUP', 'COLOUR', 'GENDER', 'AGE GROUP', 'CONSUMER RATING',
#        'INITIAL PRICE IN LOCAL CURRENCY', 'CURRENT PRICE IN LOCAL CURRENCY',
#        'LOCAL CURRENCY', 'INITIAL PRICE IN EUR', 'CURRENT PRICE IN EUR',
#        'INITIAL PRICE IN SELECTED CURRENCY',
#        'CURRENT PRICE IN SELECTED CURRENCY', 'SELECTED CURRENCY',
#        'PRODUCT INTRODUCTION DATE', 'DISCOUNTED SINCE', 'PRODUCT EXIT DATE',
#        'PRODUCT DESCRIPTION', 'PRODUCT URL', 'IMAGE-SERVER URL'],
#       dtype='object')

# %%
def multiclass_logloss(actual, predicted, eps=1e-15):
    """Multi class version of Logarithmic Loss metric.
    :param actual: Array containing the actual target classes
    :param predicted: Matrix with class predictions, one probability per class
    """
    # Convert 'actual' to a binary array if it's not already:
    if len(actual.shape) == 1:
        actual2 = np.zeros((actual.shape[0], predicted.shape[1]))
        for i, val in enumerate(actual):
            actual2[i, val] = 1
        actual = actual2

    clip = np.clip(predicted, eps, 1 - eps)
    rows = actual.shape[0]
    vsota = np.sum(actual * np.log(clip))
    return -1.0 / rows * vsota

# %%
data_req = data.loc[:,["COMPANY", "COUNTRY", "ARTICLE NAME","SUBBRAND", "PRODUCT DESCRIPTION", "PRODUCT URL"]]

# %%
data_req = data_req.drop_duplicates()

# %%
data_req["description"]  = data_req["COMPANY"]  +" " + data_req["ARTICLE NAME"] +" " + data_req["PRODUCT DESCRIPTION"]

# %%
data_req.columns
# Out:
# Index(['COMPANY', 'COUNTRY', 'ARTICLE NAME', 'SUBBRAND', 'PRODUCT DESCRIPTION',
#        'PRODUCT URL', 'description'],
#       dtype='object')

# %%
data_req = data_req.drop(["COUNTRY", "ARTICLE NAME", "PRODUCT DESCRIPTION", "PRODUCT URL"], axis = 1)
data_req.columns = ["COMPANY", "subBrand", "description"]

# %%
data_req.description = data_req.description.fillna("unknown")

# %%
data_req["subBrand"] = data_req["subBrand"].str.lower()
data_req.description = data_req.description.str.lower()

# %%
from sklearn import preprocessing
lbl_enc = preprocessing.LabelEncoder()
y = lbl_enc.fit_transform(data_req["subBrand"].fillna("unknown"))

# %%
X = ["description", "COMPANY"]

# %%
data_req["subBrand"].value_counts()
# Out:
# performance       33771
# sport inspired    27764
# Name: subBrand, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain, xvalid, ytrain, yvalid = train_test_split(data_req[X], y, 
                                                  stratify=y, 
                                                  random_state=42, 
                                                  test_size=0.1, shuffle=True)

# %%
# load the GloVe vectors in a dictionary:

# embeddings_index = {}
# f = open('D:/GPMT/fasttext/cc.de.300.vec', encoding="utf-8")
# for line in tqdm(f):
#     values = line.split()
#     word = values[0]
#     coefs = np.asarray(values[1:], dtype='float32')
#     embeddings_index[word] = coefs
# f.close()

# print('Found %s word vectors.' % len(embeddings_index))
# Out:
# 2000001it [04:19, 7693.77it/s]
# Found 2000000 word vectors.

# %%
# we need to binarize the labels for the neural net
ytrain_enc = np_utils.to_categorical(ytrain)
yvalid_enc = np_utils.to_categorical(yvalid)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
chk = le.fit_transform(data["SPORTS CATEGORY"])

# %%
# using keras tokenizer here
token = text.Tokenizer(num_words=None)
max_len = 100

token.fit_on_texts(list(xtrain.description) + list(xvalid.description))
xtrain_seq = token.texts_to_sequences(xtrain.description)
xvalid_seq = token.texts_to_sequences(xvalid.description)

# zero pad the sequences
xtrain_pad = sequence.pad_sequences(xtrain_seq, maxlen=max_len)
xvalid_pad = sequence.pad_sequences(xvalid_seq, maxlen=max_len)

#word_index = token.word_index

# %%
xtrain_pad
# Out:
# array([[    0,     0,     0, ...,   493,    18, 49215],
#        [    0,     0,     0, ...,     0,     0,    14],
#        [    0,     0,     0, ...,    12,    11,    13],
#        ...,
#        [    0,     0,     0, ..., 45219,     9,    29],
#        [    0,     0,     0, ...,  2324, 70057,  2324],
#        [    0,     0,     0, ...,     0,     0,    14]])

# %%
xtrain_seq
# Out:
# [[16402], [841]]

# %%
# create an embedding matrix for the words we have in the dataset
#embeddings_index = {}
# embedding_matrix = np.zeros((len(word_index) + 1, 300))
# for word, i in tqdm(word_index.items()):
#     embedding_vector = embeddings_index.get(word)
#     if embedding_vector is not None:
#         embedding_matrix[i] = embedding_vector
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 126948/126948 [00:04<00:00, 31223.79it/s]

# %%
embedding_matrix.shape
# Out:
# (126949, 300)

# %%
import gensim
# Out:
# C:\Users\narendran.thesma\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
import tinysegmenter
segmenter = tinysegmenter.TinySegmenter()

# %%
#word_chk = segmenter.tokenize(list(xtrain.description[2]))
tokenized_text = [segmenter.tokenize(x) for x in xtrain.description ]

# %%
word_model = gensim.models.Word2Vec(tokenized_text, size=300, min_count=1, window=5, iter=1)

# %%
# from nltk import word_tokenize
# tokenized_text = [word_tokenize(x) for x in xtrain.description ]

# %%
# word_model = gensim.models.Word2Vec(tokenized_text, size=100, min_count=1, window=5, iter=5)

# %%
word_model.wv.vocab
# Out:
# {'nike': <gensim.models.keyedvectors.Vocab at 0x27d21e16198>,
#  ' ': <gensim.models.keyedvectors.Vocab at 0x27d21e16da0>,
#  'ナイキ': <gensim.models.keyedvectors.Vocab at 0x27d21f59d68>,
#  'エピック': <gensim.models.keyedvectors.Vocab at 0x27d21f59e10>,
#  'ラックス': <gensim.models.keyedvectors.Vocab at 0x27d21f59e80>,
#  'ウィメンズ': <gensim.models.keyedvectors.Vocab at 0x27d21f59ef0>,
#  'ランニングタンクトップ': <gensim.models.keyedvectors.Vocab at 0x27d21f59f60>,
#  'は': <gensim.models.keyedvectors.Vocab at 0x27d21f59f98>,
#  '、': <gensim.models.keyedvectors.Vocab at 0x27d21f59fd0>,
#  '速乾': <gensim.models.keyedvectors.Vocab at 0x27d21f59cf8>,
#  '性': <gensim.models.keyedvectors.Vocab at 0x27d21f59d30>,
#  'に': <gensim.models.keyedvectors.Vocab at 0x27d21f59da0>,
#  '優れ': <gensim.models.keyedvectors.Vocab at 0x27d21f59dd8>,
#  'た': <gensim.models.keyedvectors.Vocab at 0x27d21f592b0>,
#  'コンプレッション': <gensim.models.keyedvectors.Vocab at 0x27d2ba36048>,
#  '素材': <gensim.models.keyedvectors.Vocab at 0x27d2ba36080>,
#  'を': <gensim.models.keyedvectors.Vocab at 0x27d2ba360b8>,
#  '使用': <gensim.models.keyedvectors.Vocab at 0x27d2ba360f0>,
#  '。': <gensim.models.keyedvectors.Vocab at 0x27d2ba36128>,
#  'ランニング': <gensim.models.keyedvectors.Vocab at 0x27d2ba36160>,
#  '中': <gensim.models.keyedvectors.Vocab at 0x27d2ba36198>,
#  'も': <gensim.models.keyedvectors.Vocab at 0x27d2ba361d0>,
#  'さらり': <gensim.models.keyedvectors.Vocab at 0x27d2ba36208>,
#  'と': <gensim.models.keyedvectors.Vocab at 0x27d2ba36240>,
#  '快適': <gensim.models.keyedvectors.Vocab at 0x27d2ba36278>,
#  'で': <gensim.models.keyedvectors.Vocab at 0x27d2ba362b0>,
#  'サポート': <gensim.models.keyedvectors.Vocab at 0x27d2ba362e8>,
#  '力': <gensim.models.keyedvectors.Vocab at 0x27d2ba36320>,
#  '着心': <gensim.models.keyedvectors.Vocab at 0x27d2ba36358>,
#  '地': <gensim.models.keyedvectors.Vocab at 0x27d2ba36390>,
#  'が': <gensim.models.keyedvectors.Vocab at 0x27d2ba363c8>,
#  '持続': <gensim.models.keyedvectors.Vocab at 0x27d2ba36400>,
#  'し': <gensim.models.keyedvectors.Vocab at 0x27d2ba36438>,
#  'ます': <gensim.models.keyedvectors.Vocab at 0x27d2ba36470>,
#  'unknown': <gensim.models.keyedvectors.Vocab at 0x27d2ba364a8>,
#  'adidas': <gensim.models.keyedvectors.Vocab at 0x27d2ba364e0>,
#  'ピュアブーストエックス': <gensim.models.keyedvectors.Vocab at 0x27d2ba36518>,
#  '【': <gensim.models.keyedvectors.Vocab at 0x27d2ba36550>,
#  'pure': <gensim.models.keyedvectors.Vocab at 0x27d2ba36588>,
#  'boost': <gensim.models.keyedvectors.Vocab at 0x27d2ba365c0>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x27d2ba365f8>,
#  'tr': <gensim.models.keyedvectors.Vocab at 0x27d2ba36630>,
#  '】': <gensim.models.keyedvectors.Vocab at 0x27d2ba36668>,
#  ' ,': <gensim.models.keyedvectors.Vocab at 0x27d2ba366a0>,
#  'サイズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba366d8>,
#  '：': <gensim.models.keyedvectors.Vocab at 0x27d2ba36710>,
#  '生産国': <gensim.models.keyedvectors.Vocab at 0x27d2ba36748>,
#  'puma': <gensim.models.keyedvectors.Vocab at 0x27d2ba36780>,
#  'twv': <gensim.models.keyedvectors.Vocab at 0x27d2ba367b8>,
#  'ピステトップ': <gensim.models.keyedvectors.Vocab at 0x27d2ba367f0>,
#  '｜': <gensim.models.keyedvectors.Vocab at 0x27d2ba36828>,
#  'フォームストライプ': <gensim.models.keyedvectors.Vocab at 0x27d2ba36860>,
#  '基調': <gensim.models.keyedvectors.Vocab at 0x27d2ba36898>,
#  '全面': <gensim.models.keyedvectors.Vocab at 0x27d2ba368d0>,
#  '撥水': <gensim.models.keyedvectors.Vocab at 0x27d2ba36908>,
#  '機能': <gensim.models.keyedvectors.Vocab at 0x27d2ba36940>,
#  '搭載': <gensim.models.keyedvectors.Vocab at 0x27d2ba36978>,
#  'の': <gensim.models.keyedvectors.Vocab at 0x27d2ba369b0>,
#  '昇華': <gensim.models.keyedvectors.Vocab at 0x27d2ba369e8>,
#  'プリント': <gensim.models.keyedvectors.Vocab at 0x27d2ba36a20>,
#  '仕様': <gensim.models.keyedvectors.Vocab at 0x27d2ba36a58>,
#  'です': <gensim.models.keyedvectors.Vocab at 0x27d2ba36a90>,
#  'プーマ': <gensim.models.keyedvectors.Vocab at 0x27d2ba36ac8>,
#  '公式': <gensim.models.keyedvectors.Vocab at 0x27d2ba36b00>,
#  'オンラインストア': <gensim.models.keyedvectors.Vocab at 0x27d2ba36b38>,
#  'reebok': <gensim.models.keyedvectors.Vocab at 0x27d2ba36b70>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x27d2ba36ba8>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x27d2ba36be0>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x27d2ba36c18>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x27d2ba36c50>,
#  '春夏': <gensim.models.keyedvectors.Vocab at 0x27d2ba36c88>,
#  'ufan': <gensim.models.keyedvectors.Vocab at 0x27d2ba36cc0>,
#  'デュアルブレンド': <gensim.models.keyedvectors.Vocab at 0x27d2ba36cf8>,
#  'ショートスリーブ': <gensim.models.keyedvectors.Vocab at 0x27d2ba36d30>,
#  'グラフィックtシャツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba36d68>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x27d2ba36da0>,
#  'リーボック': <gensim.models.keyedvectors.Vocab at 0x27d2ba36dd8>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x27d2ba36e10>,
#  '商品': <gensim.models.keyedvectors.Vocab at 0x27d2ba36e48>,
#  '概要': <gensim.models.keyedvectors.Vocab at 0x27d2ba36e80>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x27d2ba36eb8>,
#  'シングルジャージ': <gensim.models.keyedvectors.Vocab at 0x27d2ba36ef0>,
#  'グラフィックショートスリーブtシャツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba36f28>,
#  '右': <gensim.models.keyedvectors.Vocab at 0x27d2ba36f60>,
#  'フロント': <gensim.models.keyedvectors.Vocab at 0x27d2ba36f98>,
#  'メイン': <gensim.models.keyedvectors.Vocab at 0x27d2ba36fd0>,
#  'ufc': <gensim.models.keyedvectors.Vocab at 0x27d2ba39048>,
#  'や': <gensim.models.keyedvectors.Vocab at 0x27d2ba39080>,
#  'reebokロゴ': <gensim.models.keyedvectors.Vocab at 0x27d2ba390b8>,
#  '散り': <gensim.models.keyedvectors.Vocab at 0x27d2ba390f0>,
#  'ばめ': <gensim.models.keyedvectors.Vocab at 0x27d2ba39128>,
#  'クール': <gensim.models.keyedvectors.Vocab at 0x27d2ba39160>,
#  'な': <gensim.models.keyedvectors.Vocab at 0x27d2ba39198>,
#  'モデル': <gensim.models.keyedvectors.Vocab at 0x27d2ba391d0>,
#  ', ': <gensim.models.keyedvectors.Vocab at 0x27d2ba39208>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x27d2ba39240>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x27d2ba39278>,
#  'asc': <gensim.models.keyedvectors.Vocab at 0x27d2ba392b0>,
#  '_': <gensim.models.keyedvectors.Vocab at 0x27d2ba392e8>,
#  'wrap': <gensim.models.keyedvectors.Vocab at 0x27d2ba39320>,
#  'ttl': <gensim.models.keyedvectors.Vocab at 0x27d2ba39358>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x27d2ba39390>,
#  '{,': <gensim.models.keyedvectors.Vocab at 0x27d2ba393c8>,
#  'border': <gensim.models.keyedvectors.Vocab at 0x27d2ba39400>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x27d2ba39438>,
#  'bottom': <gensim.models.keyedvectors.Vocab at 0x27d2ba39470>,
#  ':': <gensim.models.keyedvectors.Vocab at 0x27d2ba394a8>,
#  'px': <gensim.models.keyedvectors.Vocab at 0x27d2ba394e0>,
#  'solid': <gensim.models.keyedvectors.Vocab at 0x27d2ba39518>,
#  '#': <gensim.models.keyedvectors.Vocab at 0x27d2ba39550>,
#  'ebebeb': <gensim.models.keyedvectors.Vocab at 0x27d2ba39588>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x27d2ba395c0>,
#  'font': <gensim.models.keyedvectors.Vocab at 0x27d2ba395f8>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x27d2ba39630>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x27d2ba39668>,
#  'bold': <gensim.models.keyedvectors.Vocab at 0x27d2ba396a0>,
#  'margin': <gensim.models.keyedvectors.Vocab at 0x27d2ba396d8>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x27d2ba39710>,
#  '}': <gensim.models.keyedvectors.Vocab at 0x27d2ba39748>,
#  'span': <gensim.models.keyedvectors.Vocab at 0x27d2ba39780>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x27d2ba397b8>,
#  " '": <gensim.models.keyedvectors.Vocab at 0x27d2ba397f0>,
#  'adineuelight': <gensim.models.keyedvectors.Vocab at 0x27d2ba39828>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x27d2ba39860>,
#  ';,': <gensim.models.keyedvectors.Vocab at 0x27d2ba39898>,
#  '},': <gensim.models.keyedvectors.Vocab at 0x27d2ba398d0>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x27d2ba39908>,
#  'txt': <gensim.models.keyedvectors.Vocab at 0x27d2ba39940>,
#  'color': <gensim.models.keyedvectors.Vocab at 0x27d2ba39978>,
#  ' #': <gensim.models.keyedvectors.Vocab at 0x27d2ba399b0>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x27d2ba399e8>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x27d2ba39a20>,
#  'height': <gensim.models.keyedvectors.Vocab at 0x27d2ba39a58>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x27d2ba39a90>,
#  'list': <gensim.models.keyedvectors.Vocab at 0x27d2ba39ac8>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x27d2ba39b00>,
#  'style': <gensim.models.keyedvectors.Vocab at 0x27d2ba39b38>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x27d2ba39b70>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x27d2ba39ba8>,
#  'display': <gensim.models.keyedvectors.Vocab at 0x27d2ba39be0>,
#  'inline': <gensim.models.keyedvectors.Vocab at 0x27d2ba39c18>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x27d2ba39c50>,
#  'vertical': <gensim.models.keyedvectors.Vocab at 0x27d2ba39c88>,
#  'align': <gensim.models.keyedvectors.Vocab at 0x27d2ba39cc0>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x27d2ba39cf8>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x27d2ba39d30>,
#  '・': <gensim.models.keyedvectors.Vocab at 0x27d2ba39d68>,
#  "';": <gensim.models.keyedvectors.Vocab at 0x27d2ba39da0>,
#  'width': <gensim.models.keyedvectors.Vocab at 0x27d2ba39dd8>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x27d2ba39e10>,
#  'クラシック': <gensim.models.keyedvectors.Vocab at 0x27d2ba39e48>,
#  'クーリング': <gensim.models.keyedvectors.Vocab at 0x27d2ba39e80>,
#  'ミディアム': <gensim.models.keyedvectors.Vocab at 0x27d2ba39eb8>,
#  'インパクト': <gensim.models.keyedvectors.Vocab at 0x27d2ba39ef0>,
#  'スポーツブラ': <gensim.models.keyedvectors.Vocab at 0x27d2ba39f28>,
#  '抜群': <gensim.models.keyedvectors.Vocab at 0x27d2ba39f60>,
#  '冷涼': <gensim.models.keyedvectors.Vocab at 0x27d2ba39f98>,
#  '感': <gensim.models.keyedvectors.Vocab at 0x27d2ba39fd0>,
#  'ほどよい': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b048>,
#  'コンプレッションフィット': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b080>,
#  '深い': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b0b8>,
#  'レーサーバック': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b0f0>,
#  'ストラップ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b128>,
#  '採用': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b160>,
#  'ワークアウト': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b198>,
#  '提供': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b1d0>,
#  '自然': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b208>,
#  '動き': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b240>,
#  '特長': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b278>,
#  '前面': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b2b0>,
#  'ある': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b2e8>,
#  '通気': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b320>,
#  '孔付': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b358>,
#  'き': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b390>,
#  'swooshロゴ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b3c8>,
#  '強化': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b400>,
#  '発揮': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b438>,
#  'する': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b470>,
#  'メッシュ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b4a8>,
#  '取り外し': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b4e0>,
#  '可能': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b518>,
#  'パッド': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b550>,
#  '好み': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b588>,
#  '着用': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b5c0>,
#  '調整': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b5f8>,
#  'dri': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b630>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b668>,
#  'テクノロジー': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b6a0>,
#  'さ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b6d8>,
#  'キープ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b710>,
#  '詳細': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b748>,
#  'サイクリング': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b780>,
#  'ダンス': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b7b8>,
#  '有酸': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b7f0>,
#  '素': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b828>,
#  'トレーニングクラス': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b860>,
#  'など': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b898>,
#  'ミディアムインパクト': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b8d0>,
#  'スポーツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b908>,
#  '最適': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b940>,
#  '本体': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b978>,
#  '/': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b9b0>,
#  '裏地': <gensim.models.keyedvectors.Vocab at 0x27d2ba4b9e8>,
#  'リサイクルポリエステル': <gensim.models.keyedvectors.Vocab at 0x27d2ba4ba20>,
#  '％': <gensim.models.keyedvectors.Vocab at 0x27d2ba4ba58>,
#  'スパンデックス': <gensim.models.keyedvectors.Vocab at 0x27d2ba4ba90>,
#  '背面': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bac8>,
#  '中央': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bb00>,
#  'ポリエステル': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bb38>,
#  '縁': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bb70>,
#  'ナイロン': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bba8>,
#  '表地': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bbe0>,
#  '洗濯': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bc18>,
#  '機洗': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bc50>,
#  'い': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bc88>,
#  '原産国': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bcc0>,
#  'スリランカ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bcf8>,
#  'テイルウィンド': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bd30>,
#  'ラン': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bd68>,
#  'ディビジョン': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bda0>,
#  '高い': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bdd8>,
#  'レーサーバックデザイン': <gensim.models.keyedvectors.Vocab at 0x27d2ba4be10>,
#  '涼しい': <gensim.models.keyedvectors.Vocab at 0x27d2ba4be48>,
#  'て': <gensim.models.keyedvectors.Vocab at 0x27d2ba4be80>,
#  '自由': <gensim.models.keyedvectors.Vocab at 0x27d2ba4beb8>,
#  'エア': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bef0>,
#  'マックス': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bf28>,
#  'se': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bf60>,
#  '\u3000': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bf98>,
#  'レザー': <gensim.models.keyedvectors.Vocab at 0x27d2ba4bfd0>,
#  'ベビーシューズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d048>,
#  'オリジナル': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d080>,
#  '一躍': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d0b8>,
#  '有名': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d0f0>,
#  'クッショニング': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d128>,
#  '継承': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d160>,
#  'ながら': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d198>,
#  'デザイン': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d1d0>,
#  '一新': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d208>,
#  'トート': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d240>,
#  'pt': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d278>,
#  'マチ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d2b0>,
#  '付き': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d2e8>,
#  '大容量': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d320>,
#  'トートバック': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d358>,
#  'ハンドバック': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d390>,
#  'として': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d3c8>,
#  'できる': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d400>,
#  'もちろん': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d438>,
#  'ハンドル': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d470>,
#  '長め': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d4a8>,
#  '肩': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d4e0>,
#  'かけ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d518>,
#  'ショルダーバック': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d550>,
#  '◎': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d588>,
#  'ボタン': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d5c0>,
#  'がっちり': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d5f8>,
#  '固定': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d630>,
#  'でき': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d668>,
#  'ポケット': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d6a0>,
#  'つい': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d6d8>,
#  'すぐ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d710>,
#  '取り出し': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d748>,
#  'たい': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d780>,
#  '小物': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d7b8>,
#  '入れる': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d7f0>,
#  'ぴっ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d828>,
#  'たり': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d860>,
#  'ロゴ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d898>,
#  'さりげ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d8d0>,
#  'なく': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d908>,
#  '入り': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d940>,
#  '水分': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d978>,
#  'しみ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d9b0>,
#  'にくく': <gensim.models.keyedvectors.Vocab at 0x27d2ba4d9e8>,
#  'ゴルフ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4da20>,
#  '時': <gensim.models.keyedvectors.Vocab at 0x27d2ba4da58>,
#  '普段': <gensim.models.keyedvectors.Vocab at 0x27d2ba4da90>,
#  '使い': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dac8>,
#  'もぴっ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4db00>,
#  ' 〔': <gensim.models.keyedvectors.Vocab at 0x27d2ba4db38>,
#  '〕': <gensim.models.keyedvectors.Vocab at 0x27d2ba4db70>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dba8>,
#  'bull': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dbe0>,
#  'racing': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dc18>,
#  'ディスク': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dc50>,
#  '年': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dc88>,
#  '世界': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dcc0>,
#  '初': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dcf8>,
#  'シューレース': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dd30>,
#  '無い': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dd68>,
#  'ランニングシューズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dda0>,
#  '登場': <gensim.models.keyedvectors.Vocab at 0x27d2ba4ddd8>,
#  '業界': <gensim.models.keyedvectors.Vocab at 0x27d2ba4de10>,
#  '震撼': <gensim.models.keyedvectors.Vocab at 0x27d2ba4de48>,
#  'せ': <gensim.models.keyedvectors.Vocab at 0x27d2ba4de80>,
#  'disc': <gensim.models.keyedvectors.Vocab at 0x27d2ba4deb8>,
#  'システム': <gensim.models.keyedvectors.Vocab at 0x27d2ba4def0>,
#  'スリッポン': <gensim.models.keyedvectors.Vocab at 0x27d2ba4df28>,
#  'による': <gensim.models.keyedvectors.Vocab at 0x27d2ba4df60>,
#  'フィット': <gensim.models.keyedvectors.Vocab at 0x27d2ba4df98>,
#  '向上': <gensim.models.keyedvectors.Vocab at 0x27d2ba4dfd0>,
#  'アマチュア': <gensim.models.keyedvectors.Vocab at 0x27d2ba51048>,
#  '選手': <gensim.models.keyedvectors.Vocab at 0x27d2ba51080>,
#  'から': <gensim.models.keyedvectors.Vocab at 0x27d2ba510b8>,
#  'アスリート': <gensim.models.keyedvectors.Vocab at 0x27d2ba510f0>,
#  'まで': <gensim.models.keyedvectors.Vocab at 0x27d2ba51128>,
#  '幅広': <gensim.models.keyedvectors.Vocab at 0x27d2ba51160>,
#  '層': <gensim.models.keyedvectors.Vocab at 0x27d2ba51198>,
#  '愛さ': <gensim.models.keyedvectors.Vocab at 0x27d2ba511d0>,
#  'れ': <gensim.models.keyedvectors.Vocab at 0x27d2ba51208>,
#  'その': <gensim.models.keyedvectors.Vocab at 0x27d2ba51240>,
#  '洗練': <gensim.models.keyedvectors.Vocab at 0x27d2ba51278>,
#  '独特': <gensim.models.keyedvectors.Vocab at 0x27d2ba512b0>,
#  'ルックス': <gensim.models.keyedvectors.Vocab at 0x27d2ba512e8>,
#  '特徴': <gensim.models.keyedvectors.Vocab at 0x27d2ba51320>,
#  'ひとつ': <gensim.models.keyedvectors.Vocab at 0x27d2ba51358>,
#  'また': <gensim.models.keyedvectors.Vocab at 0x27d2ba51390>,
#  '長年': <gensim.models.keyedvectors.Vocab at 0x27d2ba513c8>,
#  'わたり': <gensim.models.keyedvectors.Vocab at 0x27d2ba51400>,
#  'スニーカーフリーク': <gensim.models.keyedvectors.Vocab at 0x27d2ba51438>,
#  '注目': <gensim.models.keyedvectors.Vocab at 0x27d2ba51470>,
#  'ストリートスタイル': <gensim.models.keyedvectors.Vocab at 0x27d2ba514a8>,
#  '欠かせ': <gensim.models.keyedvectors.Vocab at 0x27d2ba514e0>,
#  'ない': <gensim.models.keyedvectors.Vocab at 0x27d2ba51518>,
#  'アイテム': <gensim.models.keyedvectors.Vocab at 0x27d2ba51550>,
#  '定番': <gensim.models.keyedvectors.Vocab at 0x27d2ba51588>,
#  'あり': <gensim.models.keyedvectors.Vocab at 0x27d2ba515c0>,
#  'シーズン': <gensim.models.keyedvectors.Vocab at 0x27d2ba515f8>,
#  '軽量': <gensim.models.keyedvectors.Vocab at 0x27d2ba51630>,
#  '心地': <gensim.models.keyedvectors.Vocab at 0x27d2ba51668>,
#  'よい': <gensim.models.keyedvectors.Vocab at 0x27d2ba516a0>,
#  'まま': <gensim.models.keyedvectors.Vocab at 0x27d2ba516d8>,
#  '新しい': <gensim.models.keyedvectors.Vocab at 0x27d2ba51710>,
#  'スニーカー': <gensim.models.keyedvectors.Vocab at 0x27d2ba51748>,
#  '本作': <gensim.models.keyedvectors.Vocab at 0x27d2ba51780>,
#  'カラーリング': <gensim.models.keyedvectors.Vocab at 0x27d2ba517b8>,
#  'プラス': <gensim.models.keyedvectors.Vocab at 0x27d2ba517f0>,
#  'シンプル': <gensim.models.keyedvectors.Vocab at 0x27d2ba51828>,
#  'モータースポーツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba51860>,
#  '観戦': <gensim.models.keyedvectors.Vocab at 0x27d2ba51898>,
#  'だけ': <gensim.models.keyedvectors.Vocab at 0x27d2ba518d0>,
#  'タウンユース': <gensim.models.keyedvectors.Vocab at 0x27d2ba51908>,
#  'おすすめ': <gensim.models.keyedvectors.Vocab at 0x27d2ba51940>,
#  'アッパー': <gensim.models.keyedvectors.Vocab at 0x27d2ba51978>,
#  '天然': <gensim.models.keyedvectors.Vocab at 0x27d2ba519b0>,
#  '皮革': <gensim.models.keyedvectors.Vocab at 0x27d2ba519e8>,
#  '＋': <gensim.models.keyedvectors.Vocab at 0x27d2ba51a20>,
#  '合成': <gensim.models.keyedvectors.Vocab at 0x27d2ba51a58>,
#  '繊維': <gensim.models.keyedvectors.Vocab at 0x27d2ba51a90>,
#  'ミッドソール': <gensim.models.keyedvectors.Vocab at 0x27d2ba51ac8>,
#  '樹脂': <gensim.models.keyedvectors.Vocab at 0x27d2ba51b00>,
#  '（': <gensim.models.keyedvectors.Vocab at 0x27d2ba51b38>,
#  'モールデッドeva': <gensim.models.keyedvectors.Vocab at 0x27d2ba51b70>,
#  '）': <gensim.models.keyedvectors.Vocab at 0x27d2ba51ba8>,
#  'アウトソール': <gensim.models.keyedvectors.Vocab at 0x27d2ba51be0>,
#  'ゴム': <gensim.models.keyedvectors.Vocab at 0x27d2ba51c18>,
#  '底': <gensim.models.keyedvectors.Vocab at 0x27d2ba51c50>,
#  'ゾーナル': <gensim.models.keyedvectors.Vocab at 0x27d2ba51c88>,
#  'スイング': <gensim.models.keyedvectors.Vocab at 0x27d2ba51cc0>,
#  'ニット': <gensim.models.keyedvectors.Vocab at 0x27d2ba51cf8>,
#  'ゴルフポロ': <gensim.models.keyedvectors.Vocab at 0x27d2ba51d30>,
#  'ピンポイント': <gensim.models.keyedvectors.Vocab at 0x27d2ba51d68>,
#  '涼し': <gensim.models.keyedvectors.Vocab at 0x27d2ba51da0>,
#  '  ': <gensim.models.keyedvectors.Vocab at 0x27d2ba51dd8>,
#  'オープンニット': <gensim.models.keyedvectors.Vocab at 0x27d2ba51e10>,
#  'パネル': <gensim.models.keyedvectors.Vocab at 0x27d2ba51e48>,
#  'コース': <gensim.models.keyedvectors.Vocab at 0x27d2ba51e80>,
#  '上': <gensim.models.keyedvectors.Vocab at 0x27d2ba51eb8>,
#  '; ': <gensim.models.keyedvectors.Vocab at 0x27d2ba51ef0>,
#  'パターン': <gensim.models.keyedvectors.Vocab at 0x27d2ba51f28>,
#  '熱': <gensim.models.keyedvectors.Vocab at 0x27d2ba51f60>,
#  'こもりやすい': <gensim.models.keyedvectors.Vocab at 0x27d2ba51f98>,
#  '部分': <gensim.models.keyedvectors.Vocab at 0x27d2ba51fd0>,
#  '状態': <gensim.models.keyedvectors.Vocab at 0x27d2ba54048>,
#  '滑らか': <gensim.models.keyedvectors.Vocab at 0x27d2ba54080>,
#  'フェミニン': <gensim.models.keyedvectors.Vocab at 0x27d2ba540b8>,
#  'v': <gensim.models.keyedvectors.Vocab at 0x27d2ba540f0>,
#  'ネック': <gensim.models.keyedvectors.Vocab at 0x27d2ba54128>,
#  '現代': <gensim.models.keyedvectors.Vocab at 0x27d2ba54160>,
#  '的': <gensim.models.keyedvectors.Vocab at 0x27d2ba54198>,
#  'スタイル': <gensim.models.keyedvectors.Vocab at 0x27d2ba541d0>,
#  '演出': <gensim.models.keyedvectors.Vocab at 0x27d2ba54208>,
#  'diamond': <gensim.models.keyedvectors.Vocab at 0x27d2ba54240>,
#  'suede': <gensim.models.keyedvectors.Vocab at 0x27d2ba54278>,
#  'スケートブランドdiamond': <gensim.models.keyedvectors.Vocab at 0x27d2ba542b0>,
#  'supply': <gensim.models.keyedvectors.Vocab at 0x27d2ba542e8>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x27d2ba54320>,
#  'コラボレーションコレクション': <gensim.models.keyedvectors.Vocab at 0x27d2ba54358>,
#  'スケート': <gensim.models.keyedvectors.Vocab at 0x27d2ba54390>,
#  '歴史': <gensim.models.keyedvectors.Vocab at 0x27d2ba543c8>,
#  'インスピレーション': <gensim.models.keyedvectors.Vocab at 0x27d2ba54400>,
#  '得': <gensim.models.keyedvectors.Vocab at 0x27d2ba54438>,
#  '象徴': <gensim.models.keyedvectors.Vocab at 0x27d2ba54470>,
#  'dna': <gensim.models.keyedvectors.Vocab at 0x27d2ba544a8>,
#  'リミックス': <gensim.models.keyedvectors.Vocab at 0x27d2ba544e0>,
#  '揃い': <gensim.models.keyedvectors.Vocab at 0x27d2ba54518>,
#  'アイコニック': <gensim.models.keyedvectors.Vocab at 0x27d2ba54550>,
#  'スウェード': <gensim.models.keyedvectors.Vocab at 0x27d2ba54588>,
#  '世代': <gensim.models.keyedvectors.Vocab at 0x27d2ba545c0>,
#  '受け入れ': <gensim.models.keyedvectors.Vocab at 0x27d2ba545f8>,
#  'られる': <gensim.models.keyedvectors.Vocab at 0x27d2ba54630>,
#  '語る': <gensim.models.keyedvectors.Vocab at 0x27d2ba54668>,
#  '欠かかす': <gensim.models.keyedvectors.Vocab at 0x27d2ba546a0>,
#  'こと': <gensim.models.keyedvectors.Vocab at 0x27d2ba546d8>,
#  '印象': <gensim.models.keyedvectors.Vocab at 0x27d2ba54710>,
#  'サイド': <gensim.models.keyedvectors.Vocab at 0x27d2ba54748>,
#  'ワニ': <gensim.models.keyedvectors.Vocab at 0x27d2ba54780>,
#  'エンボス': <gensim.models.keyedvectors.Vocab at 0x27d2ba547b8>,
#  '加工': <gensim.models.keyedvectors.Vocab at 0x27d2ba547f0>,
#  '施し': <gensim.models.keyedvectors.Vocab at 0x27d2ba54828>,
#  'ファンキー': <gensim.models.keyedvectors.Vocab at 0x27d2ba54860>,
#  'アクセント': <gensim.models.keyedvectors.Vocab at 0x27d2ba54898>,
#  '足': <gensim.models.keyedvectors.Vocab at 0x27d2ba548d0>,
#  'シュータン': <gensim.models.keyedvectors.Vocab at 0x27d2ba54908>,
#  'diamondラベル': <gensim.models.keyedvectors.Vocab at 0x27d2ba54940>,
#  'ヒール': <gensim.models.keyedvectors.Vocab at 0x27d2ba54978>,
#  'ダイヤモンド': <gensim.models.keyedvectors.Vocab at 0x27d2ba549b0>,
#  '形': <gensim.models.keyedvectors.Vocab at 0x27d2ba549e8>,
#  'fot': <gensim.models.keyedvectors.Vocab at 0x27d2ba54a20>,
#  '[': <gensim.models.keyedvectors.Vocab at 0x27d2ba54a58>,
#  ']': <gensim.models.keyedvectors.Vocab at 0x27d2ba54a90>,
#  'ネックセーター': <gensim.models.keyedvectors.Vocab at 0x27d2ba54ac8>,
#  'しっかり': <gensim.models.keyedvectors.Vocab at 0x27d2ba54b00>,
#  '細やか': <gensim.models.keyedvectors.Vocab at 0x27d2ba54b38>,
#  '編み目': <gensim.models.keyedvectors.Vocab at 0x27d2ba54b70>,
#  'ロングスリーブセーター': <gensim.models.keyedvectors.Vocab at 0x27d2ba54ba8>,
#  'どんな': <gensim.models.keyedvectors.Vocab at 0x27d2ba54be0>,
#  'コーディネート': <gensim.models.keyedvectors.Vocab at 0x27d2ba54c18>,
#  'もしっかり': <gensim.models.keyedvectors.Vocab at 0x27d2ba54c50>,
#  'マッチ': <gensim.models.keyedvectors.Vocab at 0x27d2ba54c88>,
#  'ラグランスリーブ': <gensim.models.keyedvectors.Vocab at 0x27d2ba54cc0>,
#  '肩周り': <gensim.models.keyedvectors.Vocab at 0x27d2ba54cf8>,
#  '妨げる': <gensim.models.keyedvectors.Vocab at 0x27d2ba54d30>,
#  'スムーズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba54d68>,
#  'プレイ': <gensim.models.keyedvectors.Vocab at 0x27d2ba54da0>,
#  '導き': <gensim.models.keyedvectors.Vocab at 0x27d2ba54dd8>,
#  '日常': <gensim.models.keyedvectors.Vocab at 0x27d2ba54e10>,
#  '取り入れ': <gensim.models.keyedvectors.Vocab at 0x27d2ba54e48>,
#  '一着': <gensim.models.keyedvectors.Vocab at 0x27d2ba54e80>,
#  ' [': <gensim.models.keyedvectors.Vocab at 0x27d2ba54eb8>,
#  'ニットフリース': <gensim.models.keyedvectors.Vocab at 0x27d2ba54ef0>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x27d2ba54f28>,
#  'イージー': <gensim.models.keyedvectors.Vocab at 0x27d2ba54f60>,
#  'ライダー': <gensim.models.keyedvectors.Vocab at 0x27d2ba54f98>,
#  '発表': <gensim.models.keyedvectors.Vocab at 0x27d2ba54fd0>,
#  'イージーライダー': <gensim.models.keyedvectors.Vocab at 0x27d2ba58048>,
#  'シルエット': <gensim.models.keyedvectors.Vocab at 0x27d2ba58080>,
#  '独自': <gensim.models.keyedvectors.Vocab at 0x27d2ba580b8>,
#  '"': <gensim.models.keyedvectors.Vocab at 0x27d2ba580f0>,
#  'フェダーバインソール': <gensim.models.keyedvectors.Vocab at 0x27d2ba58128>,
#  'おり': <gensim.models.keyedvectors.Vocab at 0x27d2ba58160>,
#  'クッション': <gensim.models.keyedvectors.Vocab at 0x27d2ba58198>,
#  '着地': <gensim.models.keyedvectors.Vocab at 0x27d2ba581d0>,
#  '際': <gensim.models.keyedvectors.Vocab at 0x27d2ba58208>,
#  '衝撃': <gensim.models.keyedvectors.Vocab at 0x27d2ba58240>,
#  '吸収': <gensim.models.keyedvectors.Vocab at 0x27d2ba58278>,
#  '共に': <gensim.models.keyedvectors.Vocab at 0x27d2ba582b0>,
#  '屈曲': <gensim.models.keyedvectors.Vocab at 0x27d2ba582e8>,
#  'いる': <gensim.models.keyedvectors.Vocab at 0x27d2ba58320>,
#  'ため': <gensim.models.keyedvectors.Vocab at 0x27d2ba58358>,
#  'もとも': <gensim.models.keyedvectors.Vocab at 0x27d2ba58390>,
#  'ランナー': <gensim.models.keyedvectors.Vocab at 0x27d2ba583c8>,
#  '怪我': <gensim.models.keyedvectors.Vocab at 0x27d2ba58400>,
#  '最大': <gensim.models.keyedvectors.Vocab at 0x27d2ba58438>,
#  '限': <gensim.models.keyedvectors.Vocab at 0x27d2ba58470>,
#  '軽減': <gensim.models.keyedvectors.Vocab at 0x27d2ba584a8>,
#  'よう': <gensim.models.keyedvectors.Vocab at 0x27d2ba584e0>,
#  '開発': <gensim.models.keyedvectors.Vocab at 0x27d2ba58518>,
#  '持つ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58550>,
#  '一足': <gensim.models.keyedvectors.Vocab at 0x27d2ba58588>,
#  'かつ': <gensim.models.keyedvectors.Vocab at 0x27d2ba585c0>,
#  'クリーン': <gensim.models.keyedvectors.Vocab at 0x27d2ba585f8>,
#  'スタイリッシュ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58630>,
#  '代初': <gensim.models.keyedvectors.Vocab at 0x27d2ba58668>,
#  '頭': <gensim.models.keyedvectors.Vocab at 0x27d2ba586a0>,
#  'ファッション': <gensim.models.keyedvectors.Vocab at 0x27d2ba586d8>,
#  '受け': <gensim.models.keyedvectors.Vocab at 0x27d2ba58710>,
#  'ダイカット': <gensim.models.keyedvectors.Vocab at 0x27d2ba58748>,
#  'eva': <gensim.models.keyedvectors.Vocab at 0x27d2ba58780>,
#  'こぶ状': <gensim.models.keyedvectors.Vocab at 0x27d2ba587b8>,
#  '製': <gensim.models.keyedvectors.Vocab at 0x27d2ba587f0>,
#  '対照': <gensim.models.keyedvectors.Vocab at 0x27d2ba58828>,
#  'プーマフォームストライプ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58860>,
#  'バンプ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58898>,
#  '金色': <gensim.models.keyedvectors.Vocab at 0x27d2ba588d0>,
#  'トーン': <gensim.models.keyedvectors.Vocab at 0x27d2ba58908>,
#  '描か': <gensim.models.keyedvectors.Vocab at 0x27d2ba58940>,
#  '文字': <gensim.models.keyedvectors.Vocab at 0x27d2ba58978>,
#  'スポーツウェア': <gensim.models.keyedvectors.Vocab at 0x27d2ba589b0>,
#  'ビンテージ': <gensim.models.keyedvectors.Vocab at 0x27d2ba589e8>,
#  'ウィメンズクルー': <gensim.models.keyedvectors.Vocab at 0x27d2ba58a20>,
#  'ウィメンズトップ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58a58>,
#  '柔らかく': <gensim.models.keyedvectors.Vocab at 0x27d2ba58a90>,
#  '人気': <gensim.models.keyedvectors.Vocab at 0x27d2ba58ac8>,
#  'プルオーバースタイル': <gensim.models.keyedvectors.Vocab at 0x27d2ba58b00>,
#  'リブ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58b38>,
#  'クルーネック': <gensim.models.keyedvectors.Vocab at 0x27d2ba58b70>,
#  '内側': <gensim.models.keyedvectors.Vocab at 0x27d2ba58ba8>,
#  'テーピング': <gensim.models.keyedvectors.Vocab at 0x27d2ba58be0>,
#  '実現': <gensim.models.keyedvectors.Vocab at 0x27d2ba58c18>,
#  'カフス': <gensim.models.keyedvectors.Vocab at 0x27d2ba58c50>,
#  '裾': <gensim.models.keyedvectors.Vocab at 0x27d2ba58c88>,
#  'ずれず': <gensim.models.keyedvectors.Vocab at 0x27d2ba58cc0>,
#  'オーガニックコットン': <gensim.models.keyedvectors.Vocab at 0x27d2ba58cf8>,
#  'コットン': <gensim.models.keyedvectors.Vocab at 0x27d2ba58d30>,
#  '中国': <gensim.models.keyedvectors.Vocab at 0x27d2ba58d68>,
#  'トレーニング': <gensim.models.keyedvectors.Vocab at 0x27d2ba58da0>,
#  'j': <gensim.models.keyedvectors.Vocab at 0x27d2ba58dd8>,
#  'ダッフルバッグ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58e10>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x27d2ba58e48>,
#  '大きな': <gensim.models.keyedvectors.Vocab at 0x27d2ba58e80>,
#  'ロゴマーク': <gensim.models.keyedvectors.Vocab at 0x27d2ba58eb8>,
#  'なっ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58ef0>,
#  'トレーニングjダッフルバッグ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58f28>,
#  '丸み': <gensim.models.keyedvectors.Vocab at 0x27d2ba58f60>,
#  'おしゃれ': <gensim.models.keyedvectors.Vocab at 0x27d2ba58f98>,
#  '開口': <gensim.models.keyedvectors.Vocab at 0x27d2ba58fd0>,
#  '部': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b048>,
#  '大きく': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b080>,
#  '開く': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b0b8>,
#  '荷物': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b0f0>,
#  '出し入れ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b128>,
#  'しやすくなっ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b160>,
#  '紐部': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b198>,
#  '分': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b1d0>,
#  '肩当': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b208>,
#  '付い': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b240>,
#  '重い': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b278>,
#  '痛く': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b2b0>,
#  'なる': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b2e8>,
#  '心配': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b320>,
#  'ませ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b358>,
#  'ん': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b390>,
#  '前': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b3c8>,
#  'ファスナーポケット': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b400>,
#  '入れ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b438>,
#  'られ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b470>,
#  '便利': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b4a8>,
#  '部活': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b4e0>,
#  '習い事': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b518>,
#  '旅行': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b550>,
#  '用': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b588>,
#  'シーン': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b5c0>,
#  '合わせ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b5f8>,
#  'お': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b630>,
#  'だける': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b668>,
#  'バッグ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b6a0>,
#  '容量': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b6d8>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b710>,
#  'スウェットパンツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b748>,
#  'コットンベース': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b780>,
#  '裏毛': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b7b8>,
#  '肌触り': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b7f0>,
#  '良さ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b828>,
#  'ヒップ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b860>,
#  '周り': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b898>,
#  'ゆっ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b8d0>,
#  'させ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b908>,
#  '足元': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b940>,
#  '細く': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b978>,
#  'いく': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b9b0>,
#  'まし': <gensim.models.keyedvectors.Vocab at 0x27d2ba5b9e8>,
#  'ウエスト': <gensim.models.keyedvectors.Vocab at 0x27d2ba5ba20>,
#  '紐に': <gensim.models.keyedvectors.Vocab at 0x27d2ba5ba58>,
#  'お好み': <gensim.models.keyedvectors.Vocab at 0x27d2ba5ba90>,
#  '着圧': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bac8>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bb00>,
#  'pwrcool': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bb38>,
#  't': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bb70>,
#  'シャツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bba8>,
#  '湿度': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bbe0>,
#  '長け': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bc18>,
#  '身生': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bc50>,
#  'トップス': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bc88>,
#  'フラットロックシーム': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bcc0>,
#  '縫製': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bcf8>,
#  'により': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bd30>,
#  '縫い': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bd68>,
#  '代部': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bda0>,
#  '擦れ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bdd8>,
#  '肌': <gensim.models.keyedvectors.Vocab at 0x27d2ba5be10>,
#  'ストレス': <gensim.models.keyedvectors.Vocab at 0x27d2ba5be48>,
#  'くれ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5be80>,
#  '上腕': <gensim.models.keyedvectors.Vocab at 0x27d2ba5beb8>,
#  '稼動': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bef0>,
#  '域': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bf28>,
#  '妨げ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bf60>,
#  'やすい': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bf98>,
#  '作り': <gensim.models.keyedvectors.Vocab at 0x27d2ba5bfd0>,
#  'イヤフォンコード': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f048>,
#  'ループ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f080>,
#  '配置': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f0b8>,
#  'スポーツシーン': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f0f0>,
#  '音楽': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f128>,
#  '楽しめ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f160>,
#  'リフレクティブロゴ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f198>,
#  '夜間': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f1d0>,
#  '視認': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f208>,
#  '安全': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f240>,
#  '<': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f278>,
#  'br': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f2b0>,
#  '>': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f2e8>,
#  'ストレッチピケ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f320>,
#  'ポリウレタン': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f358>,
#  'ヨガ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f390>,
#  'ロゴグラフィックtシャツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f3c8>,
#  'いれ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f400>,
#  'ライフスタイル': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f438>,
#  '使える': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f470>,
#  '汎用': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f4a8>,
#  'tシャツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f4e0>,
#  '：,': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f518>,
#  '： ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f550>,
#  '混率': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f588>,
#  'モックアイレット': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f5c0>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f5f8>,
#  'ハート': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f630>,
#  'サファリ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f668>,
#  'プーマウィメンズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f6a0>,
#  '代表': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f6d8>,
#  '認知': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f710>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f748>,
#  'コレクション': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f780>,
#  'より': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f7b8>,
#  '秋冬': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f7f0>,
#  '新作': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f828>,
#  '当アイテム': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f860>,
#  'アースカラー': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f898>,
#  'ナチュラル': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f8d0>,
#  'トレンド': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f908>,
#  'コートスタイル': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f940>,
#  'ベース': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f978>,
#  'キュート': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f9b0>,
#  'リボン': <gensim.models.keyedvectors.Vocab at 0x27d2ba5f9e8>,
#  '本': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fa20>,
#  '付属': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fa58>,
#  'カジュアル': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fa90>,
#  'スポーティー': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fac8>,
#  'エレガント': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fb00>,
#  '気分': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fb38>,
#  'によって': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fb70>,
#  'アレンジ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fba8>,
#  'クライマライト': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fbe0>,
#  'ウィメンズトレーニンググローブ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fc18>,
#  'スタイルスケープ': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fc50>,
#  'ブラック': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fc88>,
#  'コール': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fcc0>,
#  'ホワイト': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fcf8>,
#  'カジュアルスリッポンモデル': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fd30>,
#  'インソール': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fd68>,
#  '中敷き': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fda0>,
#  '反発': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fdd8>,
#  '「': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fe10>,
#  'reebokメモリーテック': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fe48>,
#  '」': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fe80>,
#  '柔らか': <gensim.models.keyedvectors.Vocab at 0x27d2ba5feb8>,
#  '履き': <gensim.models.keyedvectors.Vocab at 0x27d2ba5fef0>,
#  '一体': <gensim.models.keyedvectors.Vocab at 0x27d2ba5ff28>,
#  '成型': <gensim.models.keyedvectors.Vocab at 0x27d2ba5ff60>,
#  '事': <gensim.models.keyedvectors.Vocab at 0x27d2ba5ff98>,
#  '化': <gensim.models.keyedvectors.Vocab at 0x27d2ba5ffd0>,
#  '着脱': <gensim.models.keyedvectors.Vocab at 0x27d2ba63048>,
#  '楽': <gensim.models.keyedvectors.Vocab at 0x27d2ba63080>,
#  'スリッポンタイプ': <gensim.models.keyedvectors.Vocab at 0x27d2ba630b8>,
#  'オリジナルス': <gensim.models.keyedvectors.Vocab at 0x27d2ba630f0>,
#  'イーキューティ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63128>,
#  'eqt': <gensim.models.keyedvectors.Vocab at 0x27d2ba63160>,
#  'supportadv': <gensim.models.keyedvectors.Vocab at 0x27d2ba63198>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x27d2ba631d0>,
#  'kolor': <gensim.models.keyedvectors.Vocab at 0x27d2ba63208>,
#  'トラックジャケット': <gensim.models.keyedvectors.Vocab at 0x27d2ba63240>,
#  'レブロン': <gensim.models.keyedvectors.Vocab at 0x27d2ba63278>,
#  'アンバサダー': <gensim.models.keyedvectors.Vocab at 0x27d2ba632b0>,
#  'バックパック': <gensim.models.keyedvectors.Vocab at 0x27d2ba632e8>,
#  '耐久': <gensim.models.keyedvectors.Vocab at 0x27d2ba63320>,
#  '丈夫': <gensim.models.keyedvectors.Vocab at 0x27d2ba63358>,
#  'ボディ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63390>,
#  '耐水': <gensim.models.keyedvectors.Vocab at 0x27d2ba633c8>,
#  '布製': <gensim.models.keyedvectors.Vocab at 0x27d2ba63400>,
#  'ボトム': <gensim.models.keyedvectors.Vocab at 0x27d2ba63438>,
#  'ギア': <gensim.models.keyedvectors.Vocab at 0x27d2ba63470>,
#  '乾い': <gensim.models.keyedvectors.Vocab at 0x27d2ba634a8>,
#  '保護': <gensim.models.keyedvectors.Vocab at 0x27d2ba634e0>,
#  '\xa0': <gensim.models.keyedvectors.Vocab at 0x27d2ba63518>,
#  '用途': <gensim.models.keyedvectors.Vocab at 0x27d2ba63550>,
#  '別': <gensim.models.keyedvectors.Vocab at 0x27d2ba63588>,
#  '専用': <gensim.models.keyedvectors.Vocab at 0x27d2ba635c0>,
#  '整理': <gensim.models.keyedvectors.Vocab at 0x27d2ba635f8>,
#  '持ち運べ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63630>,
#  'メインコンパートメント': <gensim.models.keyedvectors.Vocab at 0x27d2ba63668>,
#  '物': <gensim.models.keyedvectors.Vocab at 0x27d2ba636a0>,
#  'トップローディングデザイン': <gensim.models.keyedvectors.Vocab at 0x27d2ba636d8>,
#  'インチ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63710>,
#  '電子': <gensim.models.keyedvectors.Vocab at 0x27d2ba63748>,
#  '機器': <gensim.models.keyedvectors.Vocab at 0x27d2ba63780>,
#  '収納': <gensim.models.keyedvectors.Vocab at 0x27d2ba637b8>,
#  '内部': <gensim.models.keyedvectors.Vocab at 0x27d2ba637f0>,
#  'スリーブ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63828>,
#  'ウェビング': <gensim.models.keyedvectors.Vocab at 0x27d2ba63860>,
#  'バックル': <gensim.models.keyedvectors.Vocab at 0x27d2ba63898>,
#  '上部': <gensim.models.keyedvectors.Vocab at 0x27d2ba638d0>,
#  'ロック': <gensim.models.keyedvectors.Vocab at 0x27d2ba63908>,
#  'セキュリティ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63940>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x27d2ba63978>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x27d2ba639b0>,
#  'ユニット': <gensim.models.keyedvectors.Vocab at 0x27d2ba639e8>,
#  '肩へ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63a20>,
#  '荷重': <gensim.models.keyedvectors.Vocab at 0x27d2ba63a58>,
#  '均等': <gensim.models.keyedvectors.Vocab at 0x27d2ba63a90>,
#  '分散': <gensim.models.keyedvectors.Vocab at 0x27d2ba63ac8>,
#  '備え': <gensim.models.keyedvectors.Vocab at 0x27d2ba63b00>,
#  'シューズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63b38>,
#  'コンパートメント': <gensim.models.keyedvectors.Vocab at 0x27d2ba63b70>,
#  'cm': <gensim.models.keyedvectors.Vocab at 0x27d2ba63ba8>,
#  '食品': <gensim.models.keyedvectors.Vocab at 0x27d2ba63be0>,
#  '飲料': <gensim.models.keyedvectors.Vocab at 0x27d2ba63c18>,
#  '保温': <gensim.models.keyedvectors.Vocab at 0x27d2ba63c50>,
#  '保冷': <gensim.models.keyedvectors.Vocab at 0x27d2ba63c88>,
#  '縦開き': <gensim.models.keyedvectors.Vocab at 0x27d2ba63cc0>,
#  'ポーチ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63cf8>,
#  '安定': <gensim.models.keyedvectors.Vocab at 0x27d2ba63d30>,
#  '高める': <gensim.models.keyedvectors.Vocab at 0x27d2ba63d68>,
#  'チェストストラップ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63da0>,
#  '寸法': <gensim.models.keyedvectors.Vocab at 0x27d2ba63dd8>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x27d2ba63e10>,
#  'w': <gensim.models.keyedvectors.Vocab at 0x27d2ba63e48>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x27d2ba63e80>,
#  'マジスタ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63eb8>,
#  'オーパス': <gensim.models.keyedvectors.Vocab at 0x27d2ba63ef0>,
#  'hg': <gensim.models.keyedvectors.Vocab at 0x27d2ba63f28>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x27d2ba63f60>,
#  'メンズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba63f98>,
#  'ハードグラウンド': <gensim.models.keyedvectors.Vocab at 0x27d2ba63fd0>,
#  'サッカースパイク': <gensim.models.keyedvectors.Vocab at 0x27d2ba66048>,
#  '誰': <gensim.models.keyedvectors.Vocab at 0x27d2ba66080>,
#  '止め': <gensim.models.keyedvectors.Vocab at 0x27d2ba660b8>,
#  'ゲームメイク': <gensim.models.keyedvectors.Vocab at 0x27d2ba660f0>,
#  'しなやかな': <gensim.models.keyedvectors.Vocab at 0x27d2ba66128>,
#  'カンガライト': <gensim.models.keyedvectors.Vocab at 0x27d2ba66160>,
#  '全体': <gensim.models.keyedvectors.Vocab at 0x27d2ba66198>,
#  'テクスチャー': <gensim.models.keyedvectors.Vocab at 0x27d2ba661d0>,
#  'コントロール': <gensim.models.keyedvectors.Vocab at 0x27d2ba66208>,
#  '計算': <gensim.models.keyedvectors.Vocab at 0x27d2ba66240>,
#  'スパイク': <gensim.models.keyedvectors.Vocab at 0x27d2ba66278>,
#  '硬い土': <gensim.models.keyedvectors.Vocab at 0x27d2ba662b0>,
#  '強力': <gensim.models.keyedvectors.Vocab at 0x27d2ba662e8>,
#  'トラクション': <gensim.models.keyedvectors.Vocab at 0x27d2ba66320>,
#  '沿っ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66358>,
#  'フォーム': <gensim.models.keyedvectors.Vocab at 0x27d2ba66390>,
#  'ソックライナー': <gensim.models.keyedvectors.Vocab at 0x27d2ba663c8>,
#  'なやかな': <gensim.models.keyedvectors.Vocab at 0x27d2ba66400>,
#  'ボールタッチ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66438>,
#  '下': <gensim.models.keyedvectors.Vocab at 0x27d2ba66470>,
#  'メッシュレイヤー': <gensim.models.keyedvectors.Vocab at 0x27d2ba664a8>,
#  '追求': <gensim.models.keyedvectors.Vocab at 0x27d2ba664e0>,
#  'pebax': <gensim.models.keyedvectors.Vocab at 0x27d2ba66518>,
#  '®': <gensim.models.keyedvectors.Vocab at 0x27d2ba66550>,
#  'ナイロンシャーシ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66588>,
#  '弾力': <gensim.models.keyedvectors.Vocab at 0x27d2ba665c0>,
#  'クォーターパネル': <gensim.models.keyedvectors.Vocab at 0x27d2ba665f8>,
#  'nikeskin': <gensim.models.keyedvectors.Vocab at 0x27d2ba66630>,
#  '薄型': <gensim.models.keyedvectors.Vocab at 0x27d2ba66668>,
#  'pu': <gensim.models.keyedvectors.Vocab at 0x27d2ba666a0>,
#  'フィルム': <gensim.models.keyedvectors.Vocab at 0x27d2ba666d8>,
#  '結合': <gensim.models.keyedvectors.Vocab at 0x27d2ba66710>,
#  '雨天': <gensim.models.keyedvectors.Vocab at 0x27d2ba66748>,
#  '乾燥': <gensim.models.keyedvectors.Vocab at 0x27d2ba66780>,
#  '天候': <gensim.models.keyedvectors.Vocab at 0x27d2ba667b8>,
#  'ボールコントロール': <gensim.models.keyedvectors.Vocab at 0x27d2ba667f0>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x27d2ba66828>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x27d2ba66860>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x27d2ba66898>,
#  'acc': <gensim.models.keyedvectors.Vocab at 0x27d2ba668d0>,
#  '丸い': <gensim.models.keyedvectors.Vocab at 0x27d2ba66908>,
#  '形状': <gensim.models.keyedvectors.Vocab at 0x27d2ba66940>,
#  'ハードグラウンドエリプティカル': <gensim.models.keyedvectors.Vocab at 0x27d2ba66978>,
#  'スタッズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba669b0>,
#  'かかと': <gensim.models.keyedvectors.Vocab at 0x27d2ba669e8>,
#  '配し': <gensim.models.keyedvectors.Vocab at 0x27d2ba66a20>,
#  'グリップ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66a58>,
#  '生む': <gensim.models.keyedvectors.Vocab at 0x27d2ba66a90>,
#  'ﾍﾞﾄﾅﾑ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66ac8>,
#  'パーカー': <gensim.models.keyedvectors.Vocab at 0x27d2ba66b00>,
#  'floral': <gensim.models.keyedvectors.Vocab at 0x27d2ba66b38>,
#  'hoodie': <gensim.models.keyedvectors.Vocab at 0x27d2ba66b70>,
#  'ウィークエンダー': <gensim.models.keyedvectors.Vocab at 0x27d2ba66ba8>,
#  'ロールトップ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66be0>,
#  'camo': <gensim.models.keyedvectors.Vocab at 0x27d2ba66c18>,
#  'バイザー': <gensim.models.keyedvectors.Vocab at 0x27d2ba66c50>,
#  '日差し': <gensim.models.keyedvectors.Vocab at 0x27d2ba66c88>,
#  '強すぎ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66cc0>,
#  '春': <gensim.models.keyedvectors.Vocab at 0x27d2ba66cf8>,
#  '初夏': <gensim.models.keyedvectors.Vocab at 0x27d2ba66d30>,
#  '秋': <gensim.models.keyedvectors.Vocab at 0x27d2ba66d68>,
#  '汗': <gensim.models.keyedvectors.Vocab at 0x27d2ba66da0>,
#  'かい': <gensim.models.keyedvectors.Vocab at 0x27d2ba66dd8>,
#  'ベタ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66e10>,
#  '付き感が': <gensim.models.keyedvectors.Vocab at 0x27d2ba66e48>,
#  'ラウンド': <gensim.models.keyedvectors.Vocab at 0x27d2ba66e80>,
#  '身だ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66eb8>,
#  'なみ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66ef0>,
#  'ピッタリ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66f28>,
#  'オーシャンカモフラージュ': <gensim.models.keyedvectors.Vocab at 0x27d2ba66f60>,
#  '柄': <gensim.models.keyedvectors.Vocab at 0x27d2ba66f98>,
#  'バック': <gensim.models.keyedvectors.Vocab at 0x27d2ba66fd0>,
#  'アジャスター': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a048>,
#  '大きさ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a080>,
#  '簡単': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a0b8>,
#  '調節': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a0f0>,
#  ' ・': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a128>,
#  'こちら': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a160>,
#  '同': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a198>,
#  'キャップコレクション': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a1d0>,
#  '展開': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a208>,
#  ' \u3000': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a240>,
#  'トラッカー': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a278>,
#  '品番': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a2b0>,
#  'ミリタリー': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a2e8>,
#  'メッシュハット': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a320>,
#  'ユーティリティ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a358>,
#  'トップ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a390>,
#  'フィットネス': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a3c8>,
#  '左': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a400>,
#  '小さ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a438>,
#  'トレーニングコレクション': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a470>,
#  '最高': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a4a8>,
#  'レベル': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a4e0>,
#  'アパレル': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a518>,
#  'evo': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a550>,
#  'グラフィック': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a588>,
#  '幾何': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a5c0>,
#  '学模': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a5f8>,
#  '様': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a630>,
#  '半袖': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a668>,
#  '眺め': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a6a0>,
#  '丈': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a6d8>,
#  'ストリート': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a710>,
#  '吸汗': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a748>,
#  '–': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a780>,
#  'drycell': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a7b8>,
#  '対応': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a7f0>,
#  '吸水': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a828>,
#  '高機': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a860>,
#  '能素': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a898>,
#  '材': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a8d0>,
#  '運動': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a908>,
#  '衣服': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a940>,
#  '内': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a978>,
#  'ドライ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a9b0>,
#  'グラフィックオールオーバープリント': <gensim.models.keyedvectors.Vocab at 0x27d2ba6a9e8>,
#  '高密': <gensim.models.keyedvectors.Vocab at 0x27d2ba6aa20>,
#  '度': <gensim.models.keyedvectors.Vocab at 0x27d2ba6aa58>,
#  '伸縮': <gensim.models.keyedvectors.Vocab at 0x27d2ba6aa90>,
#  '柔軟': <gensim.models.keyedvectors.Vocab at 0x27d2ba6aac8>,
#  'ドロップバックヘムスタイル': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ab00>,
#  'レギュラーフィット': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ab38>,
#  'tags': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ab70>,
#  'シューパック': <gensim.models.keyedvectors.Vocab at 0x27d2ba6aba8>,
#  'つま先': <gensim.models.keyedvectors.Vocab at 0x27d2ba6abe0>,
#  '無駄': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ac18>,
#  'スペース': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ac50>,
#  '取ら': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ac88>,
#  'ず': <gensim.models.keyedvectors.Vocab at 0x27d2ba6acc0>,
#  'コンパクト': <gensim.models.keyedvectors.Vocab at 0x27d2ba6acf8>,
#  '消臭': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ad30>,
#  '蘭': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ad68>,
#  '分丈': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ada0>,
#  'タイツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6add8>,
#  '花柄': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ae10>,
#  '模様': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ae48>,
#  'キーポケット': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ae80>,
#  'コイン': <gensim.models.keyedvectors.Vocab at 0x27d2ba6aeb8>,
#  '鍵': <gensim.models.keyedvectors.Vocab at 0x27d2ba6aef0>,
#  'ソック': <gensim.models.keyedvectors.Vocab at 0x27d2ba6af28>,
#  'ダート': <gensim.models.keyedvectors.Vocab at 0x27d2ba6af60>,
#  'ブリーズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6af98>,
#  'メンズシューズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6afd0>,
#  'アイコン': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d048>,
#  '地位': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d080>,
#  'へ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d0b8>,
#  '押し上げ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d0f0>,
#  '柔ら': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d128>,
#  'ソックス': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d160>,
#  '構造': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d198>,
#  'ナカワタ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d1d0>,
#  'ロングコート': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d208>,
#  '詳しい': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d240>,
#  '情報': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d278>,
#  'ご': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d2b0>,
#  '案内': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d2e8>,
#  'ショッピングページ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d320>,
#  'ダンク': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d358>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d390>,
#  'id': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d3c8>,
#  'ジブン': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d400>,
#  '上質': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d438>,
#  'ひと': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d470>,
#  '目': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d4a8>,
#  'でわかる': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d4e0>,
#  'ユニーク': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d518>,
#  '代': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d550>,
#  '一世': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d588>,
#  '風靡': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d5c0>,
#  'オリジナルモデル': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d5f8>,
#  '鮮': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d630>,
#  'やか': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d668>,
#  'カラー': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d6a0>,
#  'パーソナル': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d6d8>,
#  '斬新': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d710>,
#  'カスタマイズ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d748>,
#  '色': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d780>,
#  '選ぶ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d7b8>,
#  'swoosh': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d7f0>,
#  'パーツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d828>,
#  '好き': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d860>,
#  ' +': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d898>,
#  '変化': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d8d0>,
#  'ガムブラウン': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d908>,
#  'ユニバーシティレッド': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d940>,
#  '豊富': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d978>,
#  'オプション': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d9b0>,
#  '選択': <gensim.models.keyedvectors.Vocab at 0x27d2ba6d9e8>,
#  '感性': <gensim.models.keyedvectors.Vocab at 0x27d2ba6da20>,
#  '合っ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6da58>,
#  'らしさ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6da90>,
#  '形に': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dac8>,
#  '名前': <gensim.models.keyedvectors.Vocab at 0x27d2ba6db00>,
#  '特別': <gensim.models.keyedvectors.Vocab at 0x27d2ba6db38>,
#  '日付': <gensim.models.keyedvectors.Vocab at 0x27d2ba6db70>,
#  '言葉': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dba8>,
#  '数字': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dbe0>,
#  '刻印': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dc18>,
#  'クラウドライド': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dc50>,
#  'dmx': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dc88>,
#  'アッシュグレー': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dcc0>,
#  'ムービングエアー': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dcf8>,
#  '空気': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dd30>,
#  '動く': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dd68>,
#  '最新': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dda0>,
#  '高く': <gensim.models.keyedvectors.Vocab at 0x27d2ba6ddd8>,
#  '今': <gensim.models.keyedvectors.Vocab at 0x27d2ba6de10>,
#  '体感': <gensim.models.keyedvectors.Vocab at 0x27d2ba6de48>,
#  'ふわふわ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6de80>,
#  'まさ': <gensim.models.keyedvectors.Vocab at 0x27d2ba6deb8>,
#  '名': <gensim.models.keyedvectors.Vocab at 0x27d2ba6def0>,
#  '雲': <gensim.models.keyedvectors.Vocab at 0x27d2ba6df28>,
#  '上歩': <gensim.models.keyedvectors.Vocab at 0x27d2ba6df60>,
#  '感覚': <gensim.models.keyedvectors.Vocab at 0x27d2ba6df98>,
#  '秘密': <gensim.models.keyedvectors.Vocab at 0x27d2ba6dfd0>,
#  '入っ': <gensim.models.keyedvectors.Vocab at 0x27d2ba71048>,
#  'ムービングエアーテクノロジー': <gensim.models.keyedvectors.Vocab at 0x27d2ba71080>,
#  '歩く': <gensim.models.keyedvectors.Vocab at 0x27d2ba710b8>,
#  'たび': <gensim.models.keyedvectors.Vocab at 0x27d2ba710f0>,
#  'ポッド': <gensim.models.keyedvectors.Vocab at 0x27d2ba71128>,
#  '流動': <gensim.models.keyedvectors.Vocab at 0x27d2ba71160>,
#  '足へ': <gensim.models.keyedvectors.Vocab at 0x27d2ba71198>,
#  '負担': <gensim.models.keyedvectors.Vocab at 0x27d2ba711d0>,
#  '助ける': <gensim.models.keyedvectors.Vocab at 0x27d2ba71208>,
#  '共': <gensim.models.keyedvectors.Vocab at 0x27d2ba71240>,
#  '歩行': <gensim.models.keyedvectors.Vocab at 0x27d2ba71278>,
#  '足運び': <gensim.models.keyedvectors.Vocab at 0x27d2ba712b0>,
#  'メモリーテックマッサージ': <gensim.models.keyedvectors.Vocab at 0x27d2ba712e8>,
#  '調': <gensim.models.keyedvectors.Vocab at 0x27d2ba71320>,
#  'フィットネスウォーキング': <gensim.models.keyedvectors.Vocab at 0x27d2ba71358>,
#  '履ける': <gensim.models.keyedvectors.Vocab at 0x27d2ba71390>,
#  'sc': <gensim.models.keyedvectors.Vocab at 0x27d2ba713c8>,
#  'ナンバリングtシャツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba71400>,
#  'neo': <gensim.models.keyedvectors.Vocab at 0x27d2ba71438>,
#  'アディダスネオ': <gensim.models.keyedvectors.Vocab at 0x27d2ba71470>,
#  'スポーツミックスコーディネート': <gensim.models.keyedvectors.Vocab at 0x27d2ba714a8>,
#  'ナンバリングｔシャツ': <gensim.models.keyedvectors.Vocab at 0x27d2ba714e0>,
#  'アイスホッケーインスパイアー': <gensim.models.keyedvectors.Vocab at 0x27d2ba71518>,
#  'アクセントカラー': <gensim.models.keyedvectors.Vocab at 0x27d2ba71550>,
#  '効い': <gensim.models.keyedvectors.Vocab at 0x27d2ba71588>,
#  'ｖ': <gensim.models.keyedvectors.Vocab at 0x27d2ba715c0>,
#  'ネックライン': <gensim.models.keyedvectors.Vocab at 0x27d2ba715f8>,
#  'ナンバリング': <gensim.models.keyedvectors.Vocab at 0x27d2ba71630>,
#  '夏': <gensim.models.keyedvectors.Vocab at 0x27d2ba71668>,
#  'モチーフ': <gensim.models.keyedvectors.Vocab at 0x27d2ba716a0>,
#  'ヤシ': <gensim.models.keyedvectors.Vocab at 0x27d2ba716d8>,
#  '木': <gensim.models.keyedvectors.Vocab at 0x27d2ba71710>,
#  'オリジナルグラフィック': <gensim.models.keyedvectors.Vocab at 0x27d2ba71748>,
#  '施さ': <gensim.models.keyedvectors.Vocab at 0x27d2ba71780>,
#  ' (': <gensim.models.keyedvectors.Vocab at 0x27d2ba717b8>,
#  '着丈': <gensim.models.keyedvectors.Vocab at 0x27d2ba717f0>,
#  '㎝': <gensim.models.keyedvectors.Vocab at 0x27d2ba71828>,
#  ') ': <gensim.models.keyedvectors.Vocab at 0x27d2ba71860>,
#  '】 ': <gensim.models.keyedvectors.Vocab at 0x27d2ba71898>,
#  'アクティブ': <gensim.models.keyedvectors.Vocab at 0x27d2ba718d0>,
#  'フレッシュ': <gensim.models.keyedvectors.Vocab at 0x27d2ba71908>,
#  '若者': <gensim.models.keyedvectors.Vocab at 0x27d2ba71940>,
#  '向け': <gensim.models.keyedvectors.Vocab at 0x27d2ba71978>,
#  'デイリー': <gensim.models.keyedvectors.Vocab at 0x27d2ba719b0>,
#  '楽しめる': <gensim.models.keyedvectors.Vocab at 0x27d2ba719e8>,
#  'スポーツカジュアルスタイル': <gensim.models.keyedvectors.Vocab at 0x27d2ba71a20>,
#  '提案': <gensim.models.keyedvectors.Vocab at 0x27d2ba71a58>,
#  'レーベル': <gensim.models.keyedvectors.Vocab at 0x27d2ba71a90>,
#  '鞄': <gensim.models.keyedvectors.Vocab at 0x27d2ba71ac8>,
#  'ランナップ': <gensim.models.keyedvectors.Vocab at 0x27d2ba71b00>,
#  ...}

# %%
# from gensim.test.utils import common_texts
# from gensim.models import Word2Vec
# model = Word2Vec(common_texts[1], size=100, window=5, min_count=1, workers=4)

# %%
# type(common_texts)
# Out:
# list

# %%
# create an embedding matrix for the words we have in the dataset
#embeddings_index = {}
embedding_matrix = np.zeros((len(word_model.wv.vocab)+1, 300))
for i in range(len(word_model.wv.vocab)):
    embedding_vector = word_model.wv[word_model.wv.index2word[i]]
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %%
embedding_matrix
# Out:
# array([[-8.34841073e-01, -1.22127086e-01,  6.68775797e-01, ...,
#          2.57656127e-01,  4.58594590e-01,  7.16453910e-01],
#        [ 4.67244804e-01, -3.30790371e-01,  5.16118348e-01, ...,
#          1.11972041e-01, -4.24341589e-01,  5.47882617e-01],
#        [ 1.33656454e+00, -3.56277287e-01,  1.51411057e+00, ...,
#         -1.59505308e+00, -9.75202844e-02, -2.73133218e-01],
#        ...,
#        [ 2.82297289e-04,  8.22886534e-04,  8.22812086e-04, ...,
#         -9.80065204e-04,  1.19583026e-04,  4.64186800e-04],
#        [ 6.39223435e-04, -9.90046188e-04,  9.84076993e-04, ...,
#          1.40132196e-03, -1.04523997e-03, -2.26449061e-04],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
#word_model.wv.vocab
max_len
# Out:
# 100

# %%
from keras import optimizers

# A simple LSTM with glove embeddings and two dense layers
model = Sequential()
model.add(Embedding(len(word_model.wv.vocab) + 1,
                     300,
                     weights=[embedding_matrix],
                     input_length=max_len,
                     trainable=True))
model.add(SpatialDropout1D(0.3))
model.add(LSTM(100, dropout=0.3, recurrent_dropout=0.3))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.8))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.8))

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(2))
model.add(Activation('softmax'))

#sgd = optimizers.SGD(lr=0.00001, decay=1e-5, momentum=0.8, nesterov=True)
rmsprop = optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
model.compile(loss='categorical_crossentropy', optimizer= rmsprop)

# %%
embed = Embedding(len(word_index) + 1,
                     300,
                     weights=[embedding_matrix],
                     input_length=max_len,
                     trainable=False)
embed

# %%
from keras.layers import Flatten
from keras.layers import Concatenate

embed = Sequential([Embedding(len(word_index) + 1,
                     300,
                     weights=[embedding_matrix],
                     input_length=max_len,
                     trainable=False), SpatialDropout1D(0.3), LSTM(100, dropout=0.3, recurrent_dropout=0.3)])

#flatten = Flatten()(embed)

#dropout1 = SpatialDropout1D(0.3)(embed)

#lstm = LSTM(100, dropout=0.3, recurrent_dropout=0.3)(flatten)

agei = Input(shape=(len(chk),))

conc = Concatenate()([embed, agei],axis = 0)

dens1 = Dense(1024, activation='relu')(conc)
dropout2 = Dropout(0.8)(dens1)

dens2 = Dense(1024, activation='relu')(dens1)
dropout3 = Dropout(0.8)(dens2)

dens3 = Dense(512, activation='relu')(dropout3)
dropout4 = Dropout(0.4)(dens3)

dens4 = Dense(256, activation='relu')(dropout4)
dropout5 = Dropout(0.3)(dens4)

dens5 = Dense(128, activation='relu')(dropout5)
dropout6 = Dropout(0.3)(dens5)

dens6 = Dense(2)(dropout6)

acti = Activation('softmax')(dens6)

model = model.add([embed, chk], acti)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-cefa1ba106a0> in <module>()
#       2 from keras.layers import Concatenate
#       3
# ----> 4 embed = Sequential([Embedding(len(word_index) + 1,
#       5                      300,
#       6                      weights=[embedding_matrix],
#
# NameError: name 'word_index' is not defined

# %%
from keras.layers import Input, Embedding, LSTM, Dense
from keras.models import Model

# Headline input: meant to receive sequences of 100 integers, between 1 and 10000.
# Note that we can name any layer by passing it a "name" argument.
main_input = Input(shape=(len(chk),), dtype='int32', name='main_input')

# This embedding layer will encode the input sequence
# into a sequence of dense 512-dimensional vectors.
x = Embedding(output_dim=Embedding(len(word_index) + 1, weights=[embedding_matrix],
                     input_length=max_len,
                     trainable=False)(main_input)

# A LSTM will transform the vector sequence into a single vector,
# containing information about the entire sequence
lstm_out = LSTM(32)(x)

# %%
xvalid_pad
# Out:
# array([[    0,     0,     0, ...,     5,  3983,  2974],
#        [    0,     0,     0, ...,  5195,  1098,  6425],
#        [    0,     0,     0, ...,    99,     7,   186],
#        ...,
#        [    0,     0,     0, ...,    74,   482,    77],
#        [    0,     0,     0, ...,    21,     9,    52],
#        [    0,     0,     0, ...,  1656,   235, 36044]])

# %%
model.fit(xtrain_pad, y=ytrain_enc, batch_size=128, epochs=10, verbose=1, validation_data=(xvalid_pad, yvalid_enc))
# Out:
# Train on 55381 samples, validate on 6154 samples
# Epoch 1/10
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-130-77d0ea19659c> in <module>()
# ----> 1 model.fit(xtrain_pad, y=ytrain_enc, batch_size=128, epochs=10, verbose=1, validation_data=(xvalid_pad, yvalid_enc))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
# -> 1454               self._session._session, self._handle, args, status, None)
#    1455
#    1456     def __del__(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     517             None, None,
#     518             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 519             c_api.TF_GetCode(self.status.status))
#     520     # Delete the underlying status object from memory otherwise it stays alive
#     521     # as there is a reference to status from this from the traceback due to
#
# InvalidArgumentError: indices[13,99] = 39422 is not in [0, 36236)
# 	 [[Node: embedding_8/embedding_lookup = GatherV2[Taxis=DT_INT32, Tindices=DT_INT32, Tparams=DT_FLOAT, _class=["loc:@training_4/RMSprop/Assign_1"], _device="/job:localhost/replica:0/task:0/device:CPU:0"](embedding_8/embeddings/read, embedding_8/Cast, training_4/RMSprop/gradients/embedding_8/embedding_lookup_grad/concat/axis)]]

# %%
predictions = model.predict(xvalid_pad)

# %%
predict_label = [np.argmax(i) for i in predictions]

# %%
predict_label = lbl_enc.inverse_transform(predict_label)

# %%
yvalid_label = lbl_enc.inverse_transform(yvalid)

# %%
test_df = pd.DataFrame({'description' : xvalid, 'actuals' : yvalid_label, 'predictions' : predict_label})

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix

# %%
f1_score(test_df.actuals, test_df.predictions,average="macro")

# %%
accuracy_score(test_df.actuals, test_df.predictions)
