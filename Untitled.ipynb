# %%
import pandas as pd

# %%
data = pd.read_csv("D:/GPMT/Merged/JPN-1/data_2018_joined_deu.csv", encoding = "utf-8")
data.head()
# Out:
# C:\Users\narendran.thesma\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (20,25,27,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0        date companyName currency language countryName  \
# 0           0  01/01/2018      adidas      JPY    ja-JP         jpn
# 1           1  01/08/2018      adidas      JPY    ja-JP         jpn
# 2           2  01/16/2018      adidas      JPY    ja-JP         jpn
# 3           3  01/22/2018      adidas      JPY    ja-JP         jpn
# 4           4  01/30/2018      adidas      JPY    ja-JP         jpn
#
#   distributorName ageGroup articleId                 colors  \
# 0        own ecom   adults    AA2303  ホワイト/ミディアムグレイヘザー/ホワイト
# 1        own ecom   adults    AA2303  ホワイト/ミディアムグレイヘザー/ホワイト
# 2        own ecom   adults    AA2303  ホワイト/ミディアムグレイヘザー/ホワイト
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0        date companyName currency language countryName  \
# 0           0  01/01/2018      adidas      JPY    ja-JP         jpn
# 1           1  01/08/2018      adidas      JPY    ja-JP         jpn
# 2           2  01/16/2018      adidas      JPY    ja-JP         jpn
# 3           3  01/22/2018      adidas      JPY    ja-JP         jpn
# 4           4  01/30/2018      adidas      JPY    ja-JP         jpn
# 5           5  02/07/2018      adidas      JPY    ja-JP         jpn
# 6           6  02/14/2018      adidas      JPY    ja-JP         jpn
# 7           7  02/19/2018      adidas      JPY    ja-JP         jpn
# 8           8  02/27/2018      adidas      JPY    ja-JP         jpn
# 9           9  03/08/2018      adidas      JPY    ja-JP         jpn
#
#   distributorName ageGroup articleId                 colors  \
# 0        own ecom   adults    AA2303  ホワイト/ミディアムグレイヘザー/ホワイト
# 1        own ecom   adults    AA2303  ホワイト/ミディアムグレイヘザー/ホワイト
# ...

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
# Out:
# C:\Users\narendran.thesma\AppData\Local\Continuum\anaconda3\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
from gensim.test.utils import common_texts

# %%
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %%
import spacy
# Out:
# C:\Users\narendran.thesma\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Pool size changed, may indicate binary incompatibility. Expected 48 from C header, got 64 from PyObject
#   return f(*args, **kwds)
# C:\Users\narendran.thesma\AppData\Local\Continuum\anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: cymem.cymem.Address size changed, may indicate binary incompatibility. Expected 24 from C header, got 40 from PyObject
#   return f(*args, **kwds)

# %%
#nlp = spacy.load('xx')

# %%
from janome.tokenizer import Tokenizer as janome_tokenizer

# %%
token_object = janome_tokenizer()

# %%
data.description = data.description.fillna("unknown")

# %%
# %%time
chk = [x.surface for y in data.description for x in token_object.tokenize(y)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# <timed exec> in <listcomp>(.0)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\janome\tokenizer.py in tokenize(self, text, stream, wakati, baseform_unk)
#     192             return self.__tokenize_stream(text, wakati, baseform_unk)
#     193         else:
# --> 194             return list(self.__tokenize_stream(text, wakati, baseform_unk))
#     195
#     196     def __tokenize_stream(self, text, wakati, baseform_unk):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\janome\tokenizer.py in __tokenize_stream(self, text, wakati, baseform_unk)
#     199         processed = 0
#     200         while processed < text_length:
# --> 201             tokens, pos = self.__tokenize_partial(text[processed:], wakati, baseform_unk)
#     202             for token in tokens:
# ...

# %%
data.description[37]
# Out:
# nan
